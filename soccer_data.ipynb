# %%
import pandas as pd
from sqlalchemy import create_engine
import datetime as dt
from config import password

# %%
# Read in data
df = pd.read_csv("Resources/soccer_data_raw.csv")
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %% [markdown]
# ## Transform Data

# %%
# Separate month and year
yr = df["date"].str.split("-")
year = [y[0] for y in yr]
month = [y[1] for y in yr]

# Add new columns
df["year"] = year
df["month"] = month

df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral  year month
# 0  Scotland    False  1872    11
# 1   England    False  1873    03
# 2  Scotland    False  1874    03
# 3   England    False  1875    03
# 4  Scotland    False  1876    03

# %%
# Map months to a season (summer or winter)
# Summer = April - September
# Winter = October - March

month_num = [int(month_str) for month_str in df['month']]

season_list = []

for m in month_num:
    if 4 <= m <= 9:
        season = 'summer'
    else:
        season = 'winter'
    season_list.append(season)

# %%
# Convert month number to month text
month_list = []

for month in month_num:
    m = dt.date(1111, month, 1).strftime('%B')
    month_list.append(m)

# %%
# Delete numerical month column
del df['month']

# Add new month column
df['month'] = month_list

# Add season column
df['season'] = season_list

# %%
# Rearrange columns in data frame
df = df[['date', 'year', 'month', 'home_team', 'away_team', 'home_score', 'away_score', 'tournament', 
         'city', 'country', 'neutral', 'season']]
df.head()
# Out:
#          date  year     month home_team away_team  home_score  away_score  \
# 0  1872-11-30  1872  November  Scotland   England           0           0
# 1  1873-03-08  1873     March   England  Scotland           4           2
# 2  1874-03-07  1874     March  Scotland   England           2           1
# 3  1875-03-06  1875     March   England  Scotland           2           2
# 4  1876-03-04  1876     March  Scotland   England           3           0
#
#   tournament     city   country  neutral  season
# 0   Friendly  Glasgow  Scotland    False  winter
# 1   Friendly   London   England    False  winter
# 2   Friendly  Glasgow  Scotland    False  winter
# 3   Friendly   London   England    False  winter
# 4   Friendly  Glasgow  Scotland    False  winter

# %%
# Reset index
df2 = df.reset_index()

# Rename index column to id
df2 = df2.rename(columns={'index':'id'})

# Set index to id column
df2 = df2.set_index('id')
df2.head()
# Out:
#           date  year     month home_team away_team  home_score  away_score  \
# id
# 0   1872-11-30  1872  November  Scotland   England           0           0
# 1   1873-03-08  1873     March   England  Scotland           4           2
# 2   1874-03-07  1874     March  Scotland   England           2           1
# 3   1875-03-06  1875     March   England  Scotland           2           2
# 4   1876-03-04  1876     March  Scotland   England           3           0
#
#    tournament     city   country  neutral  season
# id
# 0    Friendly  Glasgow  Scotland    False  winter
# 1    Friendly   London   England    False  winter
# 2    Friendly  Glasgow  Scotland    False  winter
# 3    Friendly   London   England    False  winter
# 4    Friendly  Glasgow  Scotland    False  winter

# %% [markdown]
# ## Connect & Load Into Database

# %%
# Create connection
engine = create_engine(f'postgresql+psycopg2://postgres:{password}@localhost:5432/olympics_db')

# Confirm table
engine.table_names()
# Out:
# ['athletes', 'regions', 'summer', 'winter', 'country', 'soccer']

# %%
# Load data frame to database
df2.to_sql(name='soccer', con=engine, if_exists='append', index=True)

# %%
# Confirm data has been added
pd.read_sql_query('SELECT * FROM soccer', con=engine).head()
